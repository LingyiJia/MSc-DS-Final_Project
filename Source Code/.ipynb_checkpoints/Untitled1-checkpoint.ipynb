# %%
import numpy as np
import pandas as pd
# %load_ext rpy2.ipython
# Out:
# D:\Lingyi\Mysoftware\Anaconda3\envs\pytorch\lib\site-packages\rpy2\robjects\packages.py:366: UserWarning: The symbol 'quartz' is not in this R namespace/package.
#   warnings.warn(

# %%
# %%R
# # load LMER libraries
# library(lme4)
# library(lmerTest)
# Out:
# R[write to console]: Loading required package: Matrix
#
# R[write to console]:
# Attaching package: 'lmerTest'
#
#
# R[write to console]: The following object is masked from 'package:lme4':
#
#     lmer
#
#
# R[write to console]: The following object is masked from 'package:stats':
#
#     step

# %%
from pymer4.models import Lmer

# %%
data= pd.read_csv("new_pullreq.csv")
data
# Out:
#               id  project_id           ownername               reponame  \
# 0              1    13708387           stylelint              stylelint
# 1              2   100297899    Joaogarciadelima            checklistos
# 2              3    93139005          binary-com            SmartCharts
# 3              4    15059440         letsencrypt                boulder
# 4              5    29684214               PyCQA                astroid
# ...          ...         ...                 ...                    ...
# 3347932  3347933    30544060  Kronos-Integration  kronos-service-consul
# 3347933  3347934        1142           saltstack                   salt
# 3347934  3347935    31499094              mjmlio                   mjml
# 3347935  3347936       55317             zotonic                zotonic
# 3347936  3347937     5660659           ikasanEIP                 ikasan
#
#          merged_or_not  lifetime_minutes  mergetime_minutes  num_commits  \
# 0                    1               237              237.0            1
# 1                    0              1410                NaN            1
# 2                    1                 4                4.0            1
# 3                    1                52               52.0            1
# 4                    1              2414             2414.0            1
# ...                ...               ...                ...          ...
# 3347932              1                 9                9.0            1
# 3347933              0              1165                NaN            1
# 3347934              1              8834             8834.0            2
# 3347935              0               703                NaN            7
# 3347936              1                44               44.0           29
#
#          src_churn  test_churn  ...  other_comment  num_comments_con  \
# 0                0           0  ...              0                 0
# 1                0           0  ...              0                 2
# 2                0           0  ...              0                 0
# 3                9         104  ...              0                 0
# 4               33          27  ...              0                 0
# ...            ...         ...  ...            ...               ...
# 3347932          0           0  ...              0                 0
# 3347933         10           0  ...              0                 1
# 3347934          6           0  ...              0                 8
# 3347935         15           0  ...              0                 0
# 3347936      26881        2207  ...              0                 2
#
#          num_code_comments  num_code_comments_con  integrator_availability  \
# 0                        0                      0                     30.0
# 1                        0                      0                    597.0
# 2                        0                      0                      2.0
# 3                        0                      0                      1.0
# 4                        0                      0                      2.0
# ...                    ...                    ...                      ...
# 3347932                  0                      0                   2537.0
# 3347933                  0                      0                     42.0
# 3347934                  0                      0                    597.0
# 3347935                  0                      0                     10.0
# 3347936                  1                      1                    332.0
#
#          friday_effect  contrib_rate_author  reopen_or_not  \
# 0                    1             0.007948              0
# 1                    0             0.830769              0
# 2                    0             0.314368              0
# 3                    0             0.117332              0
# 4                    0             0.010753              0
# ...                ...                  ...            ...
# 3347932              0             0.696970              0
# 3347933              0             0.056849              0
# 3347934              0             0.002041              0
# 3347935              0             0.000732              0
# 3347936              0             0.208889              0
#
#          first_close_minutes  reopen_num
# 0                        237           0
# 1                       1410           0
# 2                          4           0
# 3                         52           0
# 4                       2414           0
# ...                      ...         ...
# 3347932                    9           0
# 3347933                 1165           0
# 3347934                 8834           0
# 3347935                  703           0
# 3347936                   44           0
#
# [3347937 rows x 118 columns]

# %%
project_id = data[['project_id']]
#object
merged_or_not = data[['merged_or_not']]

#size of change
churn_addition = data[['churn_addition']]
churn_deletion = data[['churn_deletion']]

#Complexity
description_length = data[['description_length']]

#nature of pull request
bug_fix = data[['bug_fix']]

#test inclusion
test_inclusion = data[['test_inclusion']]

#reference of a contributor,issue or pr
hash_tag = data[['hash_tag']]
at_tag = data[['at_tag']]

#Conflict
comment_conflict = data[['comment_conflict']]

#Hotness or Relevance
pr_comment_num = data[['pr_comment_num']]
part_num_issue = data[['part_num_issue']]
part_num_commit = data[['part_num_commit']]
part_num_pr = data[['part_num_pr']]
part_num_code = data[['part_num_code']]

#Emotions
perc_inte_neg_emo = data[['perc_inte_neg_emo']]
perc_inte_pos_emo = data[['perc_inte_pos_emo']]
perc_inte_neu_emo = data[['perc_inte_neu_emo']]

#Continuous Integration
ci_exists = data[['ci_exists']]
ci_latency = data[['ci_latency']]
ci_build_num = data[['ci_build_num']]
ci_test_passed = data[['ci_test_passed']]
ci_failed_perc = data[['ci_failed_perc']]
ci_first_build_status = data[['ci_first_build_status']]
ci_last_build_status = data[['ci_last_build_status']]

# %%
print(churn_addition)
type(merged_or_not)
# Out:
#          churn_addition
# 0                     0
# 1                     0
# 2                     0
# 3                   110
# 4                    60
# ...                 ...
# 3347932               0
# 3347933               9
# 3347934               6
# 3347935               3
# 3347936           13998
#
# [3347937 rows x 1 columns]
# pandas.core.frame.DataFrame

# %%
#test 2.1
df = data [['project_id','merged_or_not','churn_addition','churn_deletion','description_length','test_inclusion','hash_tag','at_tag','comment_conflict','pr_comment_num','part_num_issue','part_num_commit','part_num_pr','part_num_code','perc_inte_neg_emo','perc_inte_pos_emo','perc_inte_neu_emo','ci_exists','ci_latency','ci_build_num','ci_test_passed','ci_failed_perc']]

# %%
#jj test 3.1
model = Lmer('merged_or_not~churn_addition+churn_deletion+test_inclusion+hash_tag+at_tag+comment_conflict+pr_comment_num+part_num_issue+part_num_commit+part_num_pr+part_num_code+perc_inte_neg_emo+perc_inte_pos_emo+perc_inte_neu_emo+ci_exists+ci_latency+ci_build_num+ci_test_passed+ci_failed_perc+(1|project_id)',data=df)

# %%
display(model.fit())
# Out:
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Formula: merged_or_not~churn_addition+churn_deletion+test_inclusion+hash_tag+at_tag+comment_conflict+pr_comment_num+part_num_issue+part_num_commit+part_num_pr+part_num_code+perc_inte_neg_emo+perc_inte_pos_emo+perc_inte_neu_emo+ci_exists+ci_latency+ci_build_num+ci_test_passed+ci_failed_perc+(1|project_id)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 3347937	 Groups: {'project_id': 7126.0}
#
# Log-likelihood: -465674.810 	 AIC: 931349.620
#
# Random effects:
#
#                    Name    Var    Std
# project_id  (Intercept)  0.022  0.148
# Residual                 0.105  0.325
#
# No random effect correlations specified
#
# Fixed effects:
#                    Estimate  2.5_ci  97.5_ci     SE           DF   T-stat  \
# (Intercept)           1.057   1.052    1.061  0.002    14958.504  471.038
# churn_addition       -0.000  -0.000   -0.000  0.000  1541619.329   -3.323
# churn_deletion        0.000   0.000    0.000  0.000  1544170.369    2.235
# test_inclusion        0.022   0.021    0.024  0.001  1545477.430   30.800
# hash_tag              0.024   0.022    0.025  0.001  1545631.629   35.262
# at_tag                0.004   0.002    0.005  0.001  1544411.557    4.831
# comment_conflict      0.023   0.018    0.027  0.002  1539892.711    9.879
# pr_comment_num        0.000   0.000    0.000  0.000  1540136.029    6.912
# part_num_issue       -0.055  -0.055   -0.054  0.000  1545659.987 -189.522
# part_num_commit      -0.010  -0.017   -0.004  0.003  1539626.053   -3.112
# part_num_pr           0.020   0.013    0.027  0.004  1539647.680    5.531
# part_num_code        -0.002  -0.009    0.006  0.004  1539642.438   -0.432
# perc_inte_neg_emo     0.028   0.023    0.034  0.003  1540402.305   10.100
# perc_inte_pos_emo     0.085   0.082    0.087  0.001  1545333.273   68.844
# perc_inte_neu_emo     0.017   0.016    0.019  0.001  1543492.726   19.711
# ci_latency            0.000   0.000    0.000  0.000  1545095.002    8.098
# ci_build_num          0.000   0.000    0.000  0.000  1544844.608    7.565
# ci_test_passed       -0.157  -0.160   -0.155  0.001  1543545.737 -126.921
# ci_failed_perc       -0.382  -0.385   -0.378  0.002  1545643.416 -226.801
#
#                    P-val  Sig
# (Intercept)        0.000  ***
# churn_addition     0.001  ***
# churn_deletion     0.025    *
# test_inclusion     0.000  ***
# hash_tag           0.000  ***
# at_tag             0.000  ***
# comment_conflict   0.000  ***
# pr_comment_num     0.000  ***
# part_num_issue     0.000  ***
# part_num_commit    0.002   **
# part_num_pr        0.000  ***
# part_num_code      0.665
# perc_inte_neg_emo  0.000  ***
# perc_inte_pos_emo  0.000  ***
# perc_inte_neu_emo  0.000  ***
# ci_latency         0.000  ***
# ci_build_num       0.000  ***
# ci_test_passed     0.000  ***
# ci_failed_perc     0.000  ***
